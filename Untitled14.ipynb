# %% [markdown]
# <a href="https://colab.research.google.com/github/cibelemoraes/Redu-o-de-Dimensionalidade-em-Imagens-para-Redes-Neurais/blob/main/Untitled14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Binarização - Convertendo imagens em tons de cinza para imagens preto e branco onde todos os pixels possuem 0 ou 255 como valores de intensidade.

# %%
import cv2
import numpy as np

# %%
# Função para transformar a imagem para níveis de cinza e binarizar
def binarizar_imagem(image_path, limiar):
    # Carregar a imagem
    imagem_colorida = cv2.imread(image_path)

    # Converter a imagem para escala de cinza
    imagem_cinza = cv2.cvtColor(imagem_colorida, cv2.COLOR_BGR2GRAY)

    # Binarizar a imagem com base no limiar fornecido
    _, imagem_binarizada = cv2.threshold(imagem_cinza, limiar, 255, cv2.THRESH_BINARY)

    return imagem_cinza, imagem_binarizada

# %%
caminho_imagem = '/content/3x44.jpg'   # Substitua pelo caminho real da sua imagem

# %%
# Limiar para binarização (ajuste conforme necessário)
limiar_binarizacao = 128

# %%
# Obter imagens transformadas
imagem_cinza, imagem_binarizada = binarizar_imagem(caminho_imagem, limiar_binarizacao)

# %%
img = cv2.imread("/content/3x44.jpg")
cv2_imshow(img)
cv2.waitKey(0)
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
suave = cv2.GaussianBlur(img, (7, 7), 0)
(T, bin) = cv2.threshold(suave, 161, 255, cv2.THRESH_BINARY)
(T, binI) = cv2.threshold(suave, 161, 255, cv2.THRESH_BINARY_INV)
resultado = np.vstack([
    np.hstack([suave, bin]),
    np.hstack([binI, cv2.bitwise_and(img, img, mask = binI)])
])
cv2_imshow(resultado)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=177x236>
# <PIL.Image.Image image mode=L size=354x472>
# -1
